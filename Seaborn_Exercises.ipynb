# %% [markdown]
# # Seaborn Exercises
#
# Time to practice your new seaborn skills! Try to recreate the plots below (don't worry about color schemes, just the plot itself.

# %% [markdown]
# ## The Data
#
# We will be working with a famous titanic data set for these exercises. Later on we will revisit this data. For now, we'll just focus on the visualization of the data with seaborn:

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.set_style('whitegrid')

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# # Exercises
#
# ** Recreate the plots below using the titanic dataframe. There are very few hints since most of the plots can be done with just one or two lines of code and a hint would basically give away the solution. Keep careful attention to the x and y labels for hints.**
#
# ** *Note! In order to not lose the plot image, make sure you don't code in the cell that is directly above the plot, there is an extra cell above that one which won't overwrite that plot!* **

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'titanic' is a DataFrame variable you have already defined
# Replace 'titanic' with the actual variable name of your DataFrame
sns.jointplot(data=titanic, y='age', x='fare')
plt.show()

# %%
sns.histplot(data=titanic, x='fare', color='red', binwidth=18)
plt.xlabel('Fare')

plt.show()

# %%
sns.catplot(data=titanic, x='class', y='age', kind='box', hue='pclass')

# %%
 sns.catplot(data=titanic, x="class", y="age", hue="pclass", kind="swarm")
# Out:
# c:\Users\USER\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 6.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\USER\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 18.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\USER\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 14.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
palette = {"male": "blue", "female": "green"}
sns.countplot(data=titanic ,x='sex' , palette=palette)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_9592\3126386475.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=titanic ,x='sex' , palette=palette)
# <Axes: xlabel='sex', ylabel='count'>

# %%
titanic_numeric = titanic.select_dtypes(include=[float, int])
corr = titanic_numeric.corr()
sns.heatmap(corr, annot=False, cmap='coolwarm')
# Out:
# <Axes: >

# %%
sns.displot(titanic, x="age", col="sex")

# %% [markdown]
# ## #shAI Club
