# %% [markdown]
# # Matplotlib Exercises
#
# Welcome to the exercises for reviewing matplotlib! Take your time with these, Matplotlib can be tricky to understand at first. These are relatively simple plots, but they can be hard if this is your first time with matplotlib, feel free to ask about anything as you go along.
#
# Also don't worry if you find the matplotlib syntax frustrating, we actually won't be using it that often, we will switch to using seaborn and pandas built-in visualization capabilities. But, those are built-off of matplotlib, which is why it is still important to get exposure to it!
#
# ** * NOTE: ALL THE COMMANDS FOR PLOTTING A FIGURE SHOULD ALL GO IN THE SAME CELL. SEPARATING THEM OUT INTO MULTIPLE CELLS MAY CAUSE NOTHING TO SHOW UP. * **
#
# # Exercises
#
# Follow the instructions to recreate the plots using this data:
#
# ## Data

# %%
import numpy as np
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# ** Import matplotlib.pyplot as plt and set %matplotlib inline if you are using the jupyter notebook. What command do you use if you aren't using the jupyter notebook?**

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## Exercise 1
#
# ** Follow along with these steps: **
# * ** Create a figure object called fig using plt.figure() **
# * ** Use add_axes to add an axis to the figure canvas at [0,0,1,1]. Call this new axis ax. **
# * ** Plot (x,y) on that axes and set the labels and titles to match the plot below:**

# %%
fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])
ax.plot(x, y)  
ax.set_title('My First Plot') 
ax.set_xlabel('x')      
ax.set_ylabel('y ')      
plt.show()

# %%
fig = plt.figure()

ax1 = fig.add_axes([0, 0, 1, 1]) 
ax2 = fig.add_axes([0.2, 0.5, 0.2, 0.2])

ax1.set_xticks(np.arange(0, 1.1, 0.2))
ax2.set_xticks(np.arange(0, 1.1, 0.2))
ax1.set_yticks(np.arange(0, 1.1, 0.2))
ax2.set_yticks(np.arange(0, 1.1, 0.2))
# Out:
# [<matplotlib.axis.YTick at 0x1b878731bd0>,
#  <matplotlib.axis.YTick at 0x1b8786abd90>,
#  <matplotlib.axis.YTick at 0x1b87866ea90>,
#  <matplotlib.axis.YTick at 0x1b87878a7d0>,
#  <matplotlib.axis.YTick at 0x1b878789d50>,
#  <matplotlib.axis.YTick at 0x1b87878d4d0>]

# %% [markdown]
# ** Now plot (x,y) on both axes. And call your figure object to show it.**

# %%
fig = plt.figure()

ax1 = fig.add_axes([0, 0, 1, 1]) 
ax2 = fig.add_axes([0.2, 0.5, 0.2, 0.2])

ax1.plot(x, y,'red')

ax2.plot(x, y,'red')

ax1.set_xticks(np.arange(0, 101, 20))
ax2.set_xticks(np.arange(0, 101, 20))
ax1.set_yticks(np.arange(0, 201, 50))
ax2.set_yticks(np.arange(0, 201, 50))
ax2.set_xlabel('x')      
ax2.set_ylabel('y ')
ax1.set_xlabel('x')      
ax1.set_ylabel('y ')
# Out:
# Text(0, 0.5, 'y ')

# %% [markdown]
# ## Exercise 3
#
# ** Create the plot below by adding two axes to a figure object at [0,0,1,1] and [0.2,0.5,.4,.4]**

# %%
fig = plt.figure()

ax1 = fig.add_axes([0, 0, 1, 1]) 
ax2 = fig.add_axes([0.2, 0.5, 0.5, 0.4])

ax1.set_xticks(np.arange(0, 1.1, 0.2))
ax2.set_xticks(np.arange(0, 1.1, 0.2))
ax1.set_yticks(np.arange(0, 1.1, 0.2))
ax2.set_yticks(np.arange(0, 1.1, 0.2))
# Out:
# [<matplotlib.axis.YTick at 0x1b87aa68e50>,
#  <matplotlib.axis.YTick at 0x1b87aa6b050>,
#  <matplotlib.axis.YTick at 0x1b87aa2ea90>,
#  <matplotlib.axis.YTick at 0x1b87aabd790>,
#  <matplotlib.axis.YTick at 0x1b87aabf910>,
#  <matplotlib.axis.YTick at 0x1b87aac5bd0>]

# %% [markdown]
# ** Now use x,y, and z arrays to recreate the plot below. Notice the xlimits and y limits on the inserted plot:**

# %%
fig = plt.figure()

ax1 = fig.add_axes([0, 0, 1, 1]) 
ax2 = fig.add_axes([0.2, 0.5, 0.5, 0.4])

ax1.set_xticks(np.arange(0, 101, 20))
ax1.set_yticks(np.arange(0, 10001, 2000))
ax2.set_xticks(np.arange(20, 22.1, 0.5))
ax2.set_yticks(np.arange(30, 51, 5))
# Out:
# [<matplotlib.axis.YTick at 0x1b87b0242d0>,
#  <matplotlib.axis.YTick at 0x1b87b01e550>,
#  <matplotlib.axis.YTick at 0x1b87aa66350>,
#  <matplotlib.axis.YTick at 0x1b87b06c490>,
#  <matplotlib.axis.YTick at 0x1b87b06df50>]

# %% [markdown]
# ## Exercise 4
#
# ** Use plt.subplots(nrows=1, ncols=2) to create the plot below.**

# %%
fig=plt.figure()
subplot1=fig.add_subplot(1,2,1)
subplot2=fig.add_subplot(1,2,2)

# %% [markdown]
# ** Now plot (x,y) and (x,z) on the axes. Play around with the linewidth and style**

# %%
fig=plt.figure()
subplot1=fig.add_subplot(1,2,1)
subplot1.plot(x,y,'--r')
subplot2=fig.add_subplot(1,2,2)
subplot2.plot(x,z,'r')

# %% [markdown]
# ** See if you can resize the plot by adding the figsize() argument in plt.subplots() are copying and pasting your previous code.**

# %% [markdown]
# # Great Job!

# %% [markdown]
# ## #shAI Club
